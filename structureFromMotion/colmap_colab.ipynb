# %% [markdown]
# <a href="https://colab.research.google.com/github/joerowelll/COMP0132/blob/main/structureFromMotion/colmap_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # COLMAP
# This notebook is a command line interface (CLI) implementation of COLMAP Structure from Motion software; to output both sparse and dense reconstructions.

# %% [markdown]
# If the execution result of running the code cell below is 'Not connected to a GPU', you can change the runtime by going to Runtime > Change runtime type in the menu to enable a GPU accelerator, and then re-execute the code cell.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# %% [markdown]
# # Installation

# %%
# !sudo apt-get install \
    git \
    cmake \
    build-essential \
    libboost-program-options-dev \
    libboost-filesystem-dev \
    libboost-graph-dev \
    libboost-regex-dev \
    libboost-system-dev \
    libboost-test-dev \
    libeigen3-dev \
    libsuitesparse-dev \
    libfreeimage-dev \
    libgoogle-glog-dev \
    libgflags-dev \
    libglew-dev \
    qtbase5-dev \
    libqt5opengl5-dev \
    libcgal-dev \
    libcgal-qt5-dev \
    libmetis-dev
# !source ~/.bashrc
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# libboost-filesystem-dev is already the newest version (1.65.1.0ubuntu1).
# libboost-filesystem-dev set to manually installed.
# libboost-program-options-dev is already the newest version (1.65.1.0ubuntu1).
# libboost-program-options-dev set to manually installed.
# libboost-system-dev is already the newest version (1.65.1.0ubuntu1).
# libboost-system-dev set to manually installed.
# libboost-graph-dev is already the newest version (1.65.1.0ubuntu1).
# libboost-graph-dev set to manually installed.
# libboost-regex-dev is already the newest version (1.65.1.0ubuntu1).
# libboost-regex-dev set to manually installed.
# libboost-test-dev is already the newest version (1.65.1.0ubuntu1).
# libboost-test-dev set to manually installed.
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.2).
# git is already the newest version (1:2.17.1-1ubuntu0.11).
# qtbase5-dev is already the newest version (5.9.5+dfsg-0ubuntu2.6).
# qtbase5-dev set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   libamd2 libbtf1 libcamd2 libccolamd2 libcgal-qt5-13 libcgal13 libcholmod3
#   libcolamd2 libcxsparse3 libfreeimage3 libgflags2.2 libglew2.0 libgmp-dev
#   libgmpxx4ldbl libgoogle-glog0v5 libgraphblas1 libjxr0 libklu1 libldl2
#   libmetis5 libmpfr-dev libqt5opengl5 libqt5svg5 libraw16 librbio2 libspqr2
#   libsuitesparseconfig5 libumfpack5
# Suggested packages:
#   libmpfi-dev libntl-dev libeigen3-doc libmrpt-dev glew-utils gmp-doc
#   libgmp10-doc libmpfr-doc
# The following NEW packages will be installed:
#   libamd2 libbtf1 libcamd2 libccolamd2 libcgal-dev libcgal-qt5-13
#   libcgal-qt5-dev libcgal13 libcholmod3 libcolamd2 libcxsparse3 libeigen3-dev
#   libfreeimage-dev libfreeimage3 libgflags-dev libgflags2.2 libglew-dev
#   libglew2.0 libgmp-dev libgmpxx4ldbl libgoogle-glog-dev libgoogle-glog0v5
#   libgraphblas1 libjxr0 libklu1 libldl2 libmetis-dev libmetis5 libmpfr-dev
#   libqt5opengl5 libqt5opengl5-dev libqt5svg5 libraw16 librbio2 libspqr2
#   libsuitesparse-dev libsuitesparseconfig5 libumfpack5
# 0 upgraded, 38 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.5 MB of archives.
# After this operation, 77.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libqt5svg5 amd64 5.9.5-0ubuntu1.1 [129 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsuitesparseconfig5 amd64 1:5.1.2-2 [9,044 B]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libamd2 amd64 1:5.1.2-2 [19.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libbtf1 amd64 1:5.1.2-2 [10.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcamd2 amd64 1:5.1.2-2 [20.9 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libccolamd2 amd64 1:5.1.2-2 [21.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcgal13 amd64 4.11-2build1 [275 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgmpxx4ldbl amd64 2:6.1.2+dfsg-2 [8,964 B]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgmp-dev amd64 2:6.1.2+dfsg-2 [316 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmpfr-dev amd64 4.0.1-1 [249 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcgal-dev amd64 4.11-2build1 [4,410 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libqt5opengl5 amd64 5.9.5+dfsg-0ubuntu2.6 [132 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcgal-qt5-13 amd64 4.11-2build1 [93.9 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcgal-qt5-dev amd64 4.11-2build1 [122 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcolamd2 amd64 1:5.1.2-2 [16.2 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmetis5 amd64 5.1.0.dfsg-5 [169 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcholmod3 amd64 1:5.1.2-2 [300 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcxsparse3 amd64 1:5.1.2-2 [63.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgflags2.2 amd64 2.2.1-1 [72.4 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgflags-dev amd64 2.2.1-1 [86.1 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglew2.0 amd64 2.0.0-5 [140 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglew-dev amd64 2.0.0-5 [120 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgoogle-glog0v5 amd64 0.3.5-1 [50.5 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgoogle-glog-dev amd64 0.3.5-1 [73.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgraphblas1 amd64 1:5.1.2-2 [384 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjxr0 amd64 1.1-6build1 [158 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 libklu1 amd64 1:5.1.2-2 [69.3 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libldl2 amd64 1:5.1.2-2 [10.3 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmetis-dev amd64 5.1.0.dfsg-5 [5,794 B]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libqt5opengl5-dev amd64 5.9.5+dfsg-0ubuntu2.6 [36.1 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libraw16 amd64 0.18.8-1ubuntu0.3 [264 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 librbio2 amd64 1:5.1.2-2 [24.0 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libspqr2 amd64 1:5.1.2-2 [64.2 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libumfpack5 amd64 1:5.1.2-2 [229 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsuitesparse-dev amd64 1:5.1.2-2 [1,235 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libeigen3-dev all 3.3.4-4 [810 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libfreeimage3 amd64 3.17.0+ds1-5+deb9u1build0.18.04.1 [260 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libfreeimage-dev amd64 3.17.0+ds1-5+deb9u1build0.18.04.1 [18.7 kB]
# Fetched 10.5 MB in 2s (6,837 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 38.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libqt5svg5:amd64.
# (Reading database ... 155632 files and directories currently installed.)
# Preparing to unpack .../00-libqt5svg5_5.9.5-0ubuntu1.1_amd64.deb ...
# Unpacking libqt5svg5:amd64 (5.9.5-0ubuntu1.1) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../01-libsuitesparseconfig5_1%3a5.1.2-2_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../02-libamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libbtf1:amd64.
# Preparing to unpack .../03-libbtf1_1%3a5.1.2-2_amd64.deb ...
# Unpacking libbtf1:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcamd2:amd64.
# Preparing to unpack .../04-libcamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libccolamd2:amd64.
# Preparing to unpack .../05-libccolamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libccolamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcgal13:amd64.
# Preparing to unpack .../06-libcgal13_4.11-2build1_amd64.deb ...
# Unpacking libcgal13:amd64 (4.11-2build1) ...
# Selecting previously unselected package libgmpxx4ldbl:amd64.
# Preparing to unpack .../07-libgmpxx4ldbl_2%3a6.1.2+dfsg-2_amd64.deb ...
# Unpacking libgmpxx4ldbl:amd64 (2:6.1.2+dfsg-2) ...
# Selecting previously unselected package libgmp-dev:amd64.
# Preparing to unpack .../08-libgmp-dev_2%3a6.1.2+dfsg-2_amd64.deb ...
# Unpacking libgmp-dev:amd64 (2:6.1.2+dfsg-2) ...
# Selecting previously unselected package libmpfr-dev:amd64.
# Preparing to unpack .../09-libmpfr-dev_4.0.1-1_amd64.deb ...
# Unpacking libmpfr-dev:amd64 (4.0.1-1) ...
# Selecting previously unselected package libcgal-dev:amd64.
# Preparing to unpack .../10-libcgal-dev_4.11-2build1_amd64.deb ...
# Unpacking libcgal-dev:amd64 (4.11-2build1) ...
# Selecting previously unselected package libqt5opengl5:amd64.
# Preparing to unpack .../11-libqt5opengl5_5.9.5+dfsg-0ubuntu2.6_amd64.deb ...
# Unpacking libqt5opengl5:amd64 (5.9.5+dfsg-0ubuntu2.6) ...
# Selecting previously unselected package libcgal-qt5-13:amd64.
# Preparing to unpack .../12-libcgal-qt5-13_4.11-2build1_amd64.deb ...
# Unpacking libcgal-qt5-13:amd64 (4.11-2build1) ...
# Selecting previously unselected package libcgal-qt5-dev:amd64.
# Preparing to unpack .../13-libcgal-qt5-dev_4.11-2build1_amd64.deb ...
# Unpacking libcgal-qt5-dev:amd64 (4.11-2build1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../14-libcolamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libmetis5:amd64.
# Preparing to unpack .../15-libmetis5_5.1.0.dfsg-5_amd64.deb ...
# Unpacking libmetis5:amd64 (5.1.0.dfsg-5) ...
# Selecting previously unselected package libcholmod3:amd64.
# Preparing to unpack .../16-libcholmod3_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcholmod3:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcxsparse3:amd64.
# Preparing to unpack .../17-libcxsparse3_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcxsparse3:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libgflags2.2.
# Preparing to unpack .../18-libgflags2.2_2.2.1-1_amd64.deb ...
# Unpacking libgflags2.2 (2.2.1-1) ...
# Selecting previously unselected package libgflags-dev.
# Preparing to unpack .../19-libgflags-dev_2.2.1-1_amd64.deb ...
# Unpacking libgflags-dev (2.2.1-1) ...
# Selecting previously unselected package libglew2.0:amd64.
# Preparing to unpack .../20-libglew2.0_2.0.0-5_amd64.deb ...
# Unpacking libglew2.0:amd64 (2.0.0-5) ...
# Selecting previously unselected package libglew-dev:amd64.
# Preparing to unpack .../21-libglew-dev_2.0.0-5_amd64.deb ...
# Unpacking libglew-dev:amd64 (2.0.0-5) ...
# Selecting previously unselected package libgoogle-glog0v5.
# Preparing to unpack .../22-libgoogle-glog0v5_0.3.5-1_amd64.deb ...
# Unpacking libgoogle-glog0v5 (0.3.5-1) ...
# Selecting previously unselected package libgoogle-glog-dev.
# Preparing to unpack .../23-libgoogle-glog-dev_0.3.5-1_amd64.deb ...
# Unpacking libgoogle-glog-dev (0.3.5-1) ...
# Selecting previously unselected package libgraphblas1:amd64.
# Preparing to unpack .../24-libgraphblas1_1%3a5.1.2-2_amd64.deb ...
# Unpacking libgraphblas1:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libjxr0:amd64.
# Preparing to unpack .../25-libjxr0_1.1-6build1_amd64.deb ...
# Unpacking libjxr0:amd64 (1.1-6build1) ...
# Selecting previously unselected package libklu1:amd64.
# Preparing to unpack .../26-libklu1_1%3a5.1.2-2_amd64.deb ...
# Unpacking libklu1:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libldl2:amd64.
# Preparing to unpack .../27-libldl2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libldl2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libmetis-dev.
# Preparing to unpack .../28-libmetis-dev_5.1.0.dfsg-5_amd64.deb ...
# Unpacking libmetis-dev (5.1.0.dfsg-5) ...
# Selecting previously unselected package libqt5opengl5-dev:amd64.
# Preparing to unpack .../29-libqt5opengl5-dev_5.9.5+dfsg-0ubuntu2.6_amd64.deb ...
# Unpacking libqt5opengl5-dev:amd64 (5.9.5+dfsg-0ubuntu2.6) ...
# Selecting previously unselected package libraw16:amd64.
# Preparing to unpack .../30-libraw16_0.18.8-1ubuntu0.3_amd64.deb ...
# Unpacking libraw16:amd64 (0.18.8-1ubuntu0.3) ...
# Selecting previously unselected package librbio2:amd64.
# Preparing to unpack .../31-librbio2_1%3a5.1.2-2_amd64.deb ...
# Unpacking librbio2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libspqr2:amd64.
# Preparing to unpack .../32-libspqr2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libspqr2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libumfpack5:amd64.
# Preparing to unpack .../33-libumfpack5_1%3a5.1.2-2_amd64.deb ...
# Unpacking libumfpack5:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libsuitesparse-dev:amd64.
# Preparing to unpack .../34-libsuitesparse-dev_1%3a5.1.2-2_amd64.deb ...
# Unpacking libsuitesparse-dev:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libeigen3-dev.
# Preparing to unpack .../35-libeigen3-dev_3.3.4-4_all.deb ...
# Unpacking libeigen3-dev (3.3.4-4) ...
# Selecting previously unselected package libfreeimage3:amd64.
# Preparing to unpack .../36-libfreeimage3_3.17.0+ds1-5+deb9u1build0.18.04.1_amd64.deb ...
# Unpacking libfreeimage3:amd64 (3.17.0+ds1-5+deb9u1build0.18.04.1) ...
# Selecting previously unselected package libfreeimage-dev.
# Preparing to unpack .../37-libfreeimage-dev_3.17.0+ds1-5+deb9u1build0.18.04.1_amd64.deb ...
# Unpacking libfreeimage-dev (3.17.0+ds1-5+deb9u1build0.18.04.1) ...
# Setting up libbtf1:amd64 (1:5.1.2-2) ...
# Setting up libldl2:amd64 (1:5.1.2-2) ...
# Setting up libcxsparse3:amd64 (1:5.1.2-2) ...
# Setting up libgflags2.2 (2.2.1-1) ...
# Setting up libgflags-dev (2.2.1-1) ...
# Setting up libeigen3-dev (3.3.4-4) ...
# Setting up libgraphblas1:amd64 (1:5.1.2-2) ...
# Setting up libqt5opengl5:amd64 (5.9.5+dfsg-0ubuntu2.6) ...
# Setting up libjxr0:amd64 (1.1-6build1) ...
# Setting up libgoogle-glog0v5 (0.3.5-1) ...
# Setting up libqt5svg5:amd64 (5.9.5-0ubuntu1.1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Setting up libmetis5:amd64 (5.1.0.dfsg-5) ...
# Setting up libcolamd2:amd64 (1:5.1.2-2) ...
# Setting up libglew2.0:amd64 (2.0.0-5) ...
# Setting up libccolamd2:amd64 (1:5.1.2-2) ...
# Setting up libcgal13:amd64 (4.11-2build1) ...
# Setting up libgmpxx4ldbl:amd64 (2:6.1.2+dfsg-2) ...
# Setting up libglew-dev:amd64 (2.0.0-5) ...
# Setting up libraw16:amd64 (0.18.8-1ubuntu0.3) ...
# Setting up libcgal-qt5-13:amd64 (4.11-2build1) ...
# Setting up libgmp-dev:amd64 (2:6.1.2+dfsg-2) ...
# Setting up libfreeimage3:amd64 (3.17.0+ds1-5+deb9u1build0.18.04.1) ...
# Setting up librbio2:amd64 (1:5.1.2-2) ...
# Setting up libcamd2:amd64 (1:5.1.2-2) ...
# Setting up libmetis-dev (5.1.0.dfsg-5) ...
# Setting up libgoogle-glog-dev (0.3.5-1) ...
# Setting up libqt5opengl5-dev:amd64 (5.9.5+dfsg-0ubuntu2.6) ...
# Setting up libamd2:amd64 (1:5.1.2-2) ...
# Setting up libfreeimage-dev (3.17.0+ds1-5+deb9u1build0.18.04.1) ...
# Setting up libmpfr-dev:amd64 (4.0.1-1) ...
# Setting up libklu1:amd64 (1:5.1.2-2) ...
# Setting up libcgal-dev:amd64 (4.11-2build1) ...
# Setting up libcholmod3:amd64 (1:5.1.2-2) ...
# Setting up libspqr2:amd64 (1:5.1.2-2) ...
# Setting up libcgal-qt5-dev:amd64 (4.11-2build1) ...
# Setting up libumfpack5:amd64 (1:5.1.2-2) ...
# Setting up libsuitesparse-dev:amd64 (1:5.1.2-2) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %% [markdown]
# ## Install Ceres-solver (takes 10~20 minutes...)

# %%
# !sudo apt-get install libatlas-base-dev libsuitesparse-dev
# !git clone https://ceres-solver.googlesource.com/ceres-solver
# %cd ceres-solver
# !git checkout 2.0.0
# Checkout the latest release
# %mkdir build
# %cd build
# !cmake .. -DBUILD_TESTING=OFF -DBUILD_EXAMPLES=OFF
# !make
# !sudo make install

# %% [markdown]
# ## Install colmap (takes another 10~20 minutes...)

# %%
# !git clone https://github.com/colmap/colmap
# %cd colmap
# !git checkout dev
# %mkdir build
# %cd build
# !cmake ..
# !make
# !sudo make install
# !CC=/usr/bin/gcc-6 CXX=/usr/bin/g++-6 cmake ..
# Out:
# fatal: destination path 'colmap' already exists and is not an empty directory.
# /content/ceres-solver/build/colmap/build/colmap
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# mkdir: cannot create directory ‘build’: File exists
# /content/ceres-solver/build/colmap/build/colmap/build
# -- Found AMD headers in: /usr/include/suitesparse
# -- Found AMD library: /usr/lib/x86_64-linux-gnu/libamd.so
# -- Found CAMD headers in: /usr/include/suitesparse
# -- Found CAMD library: /usr/lib/x86_64-linux-gnu/libcamd.so
# -- Found CCOLAMD headers in: /usr/include/suitesparse
# -- Found CCOLAMD library: /usr/lib/x86_64-linux-gnu/libccolamd.so
# -- Found CHOLMOD headers in: /usr/include/suitesparse
# -- Found CHOLMOD library: /usr/lib/x86_64-linux-gnu/libcholmod.so
# -- Found COLAMD headers in: /usr/include/suitesparse
# -- Found COLAMD library: /usr/lib/x86_64-linux-gnu/libcolamd.so
# -- Found SPQR headers in: /usr/include/suitesparse
# -- Found SPQR library: /usr/lib/x86_64-linux-gnu/libspqr.so
# -- Found Config headers in: /usr/include/suitesparse
# -- Found Config library: /usr/lib/x86_64-linux-gnu/libsuitesparseconfig.so
# -- Did not find Intel TBB library, assuming SuiteSparseQR was not compiled with TBB.
# -- Adding librt to SuiteSparse_config libraries (required on Linux & Unix [not OSX] if SuiteSparse is compiled with timing).
# -- Found required Ceres dependency: Eigen version 3.3.4 in /usr/lib/cmake/eigen3
# -- Found required Ceres dependency: glog
# -- Found required Ceres dependency: gflags
# -- Found Ceres version: 2.2.0 installed in: /usr/local with components: [EigenSparse, SparseLinearAlgebraLibrary, LAPACK, SuiteSparse, SchurSpecializations, Multithreading]
# -- Found Eigen
# --   Includes : /usr/include/eigen3
# -- Found FreeImage
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libfreeimage.so
# -- Found Metis
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libmetis.so
# -- Found Glog
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libglog.so
# -- Found Glew
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libGLEW.so
# -- Found Qt
# --   Module : /usr/lib/x86_64-linux-gnu/cmake/Qt5Core
# --   Module : /usr/lib/x86_64-linux-gnu/cmake/Qt5OpenGL
# --   Module : /usr/lib/x86_64-linux-gnu/cmake/Qt5Widgets
# -- Found CGAL
# --   Includes : /usr//include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libCGAL.so.13.0.1
# -- Build type not specified, using Release
# -- Enabling SIMD support
# -- Enabling OpenMP support
# -- Disabling interprocedural optimization
# -- Autodetected CUDA architecture(s):  6.0
# -- Enabling CUDA support (version: 11.1, archs: sm_60)
# -- Enabling GUI support
# -- Enabling OpenGL support
# -- Disabling ccache support
# -- Disabling profiling support
# -- Enabling CGAL support
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /content/ceres-solver/build/colmap/build/colmap/build
# [  0%] Building CXX object lib/FLANN/CMakeFiles/flann.dir/flann.cpp.o
# [  0%] Building C object lib/FLANN/CMakeFiles/flann.dir/ext/lz4.c.o
# [  2%] Building C object lib/FLANN/CMakeFiles/flann.dir/ext/lz4hc.c.o
# [  2%] Linking CXX static library libflann.a
# [  2%] Built target flann
# [  2%] Building C object lib/LSD/CMakeFiles/lsd.dir/lsd.c.o
# [  2%] Linking C static library liblsd.a
# [  2%] Built target lsd
# [  2%] Building NVCC (Device) object lib/PBA/CMakeFiles/pba.dir/pba_generated_ProgramCU.cu.o
# [  4%] Building CXX object lib/PBA/CMakeFiles/pba.dir/ConfigBA.cpp.o
# [  4%] Building CXX object lib/PBA/CMakeFiles/pba.dir/CuTexImage.cpp.o
# [  4%] Building CXX object lib/PBA/CMakeFiles/pba.dir/pba.cpp.o
# [  4%] Building CXX object lib/PBA/CMakeFiles/pba.dir/SparseBundleCPU.cpp.o
# [  6%] Building CXX object lib/PBA/CMakeFiles/pba.dir/SparseBundleCU.cpp.o
# [  6%] Linking CXX static library libpba.a
# [  6%] Built target pba
# [  6%] Building CXX object lib/PoissonRecon/CMakeFiles/poisson_recon.dir/CmdLineParser.cpp.o
# [  6%] Building CXX object lib/PoissonRecon/CMakeFiles/poisson_recon.dir/Factor.cpp.o
# [  6%] Building CXX object lib/PoissonRecon/CMakeFiles/poisson_recon.dir/Geometry.cpp.o
# [  9%] Building CXX object lib/PoissonRecon/CMakeFiles/poisson_recon.dir/MarchingCubes.cpp.o
# [  9%] Building CXX object lib/PoissonRecon/CMakeFiles/poisson_recon.dir/PlyFile.cpp.o
# [  9%] Building CXX object lib/PoissonRecon/CMakeFiles/poisson_recon.dir/PoissonRecon.cpp.o
# [  9%] Building CXX object lib/PoissonRecon/CMakeFiles/poisson_recon.dir/SurfaceTrimmer.cpp.o
# [  9%] Linking CXX static library libpoisson_recon.a
# [  9%] Built target poisson_recon
# [ 11%] Building NVCC (Device) object lib/SiftGPU/CMakeFiles/sift_gpu.dir/sift_gpu_generated_ProgramCU.cu.o
# [ 11%] Building CXX object lib/SiftGPU/CMakeFiles/sift_gpu.dir/FrameBufferObject.cpp.o
# [ 11%] Building CXX object lib/SiftGPU/CMakeFiles/sift_gpu.dir/GlobalUtil.cpp.o
# [ 11%] Building CXX object lib/SiftGPU/CMakeFiles/sift_gpu.dir/GLTexImage.cpp.o
# [ 13%] Building CXX object lib/SiftGPU/CMakeFiles/sift_gpu.dir/ProgramGLSL.cpp.o
# [ 13%] Building CXX object lib/SiftGPU/CMakeFiles/sift_gpu.dir/PyramidGL.cpp.o
# [ 13%] Building CXX object lib/SiftGPU/CMakeFiles/sift_gpu.dir/ShaderMan.cpp.o
# [ 13%] Building CXX object lib/SiftGPU/CMakeFiles/sift_gpu.dir/SiftGPU.cpp.o
# [ 13%] Building CXX object lib/SiftGPU/CMakeFiles/sift_gpu.dir/SiftMatch.cpp.o
# [ 15%] Building CXX object lib/SiftGPU/CMakeFiles/sift_gpu.dir/SiftPyramid.cpp.o
# [ 15%] Building CXX object lib/SiftGPU/CMakeFiles/sift_gpu.dir/CuTexImage.cpp.o
# [ 15%] Building CXX object lib/SiftGPU/CMakeFiles/sift_gpu.dir/PyramidCU.cpp.o
# [ 15%] Building CXX object lib/SiftGPU/CMakeFiles/sift_gpu.dir/SiftMatchCU.cpp.o
# [ 15%] Linking CXX static library libsift_gpu.a
# [ 15%] Built target sift_gpu
# [ 18%] Building C object lib/SQLite/CMakeFiles/sqlite3.dir/sqlite3.c.o
# [ 18%] Linking C static library libsqlite3.a
# [ 18%] Built target sqlite3
# [ 18%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/aib.c.o
# [ 18%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/array.c.o
# [ 20%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/covdet.c.o
# [ 20%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/dsift.c.o
# [ 20%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/fisher.c.o
# [ 20%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/generic.c.o
# [ 20%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/getopt_long.c.o
# [ 22%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/gmm.c.o
# [ 22%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/hikmeans.c.o
# [ 22%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/hog.c.o
# [ 22%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/homkermap.c.o
# [ 25%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/host.c.o
# [ 25%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/ikmeans.c.o
# [ 25%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/imopv.c.o
# [ 25%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/kdtree.c.o
# [ 25%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/kmeans.c.o
# [ 27%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/lbp.c.o
# [ 27%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/liop.c.o
# [ 27%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/mathop.c.o
# [ 27%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/mser.c.o
# [ 27%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/pgm.c.o
# [ 29%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/quickshift.c.o
# [ 29%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/random.c.o
# [ 29%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/rodrigues.c.o
# [ 29%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/scalespace.c.o
# [ 31%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/sift.c.o
# [ 31%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/slic.c.o
# [ 31%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/stringop.c.o
# [ 31%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/svm.c.o
# [ 31%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/svmdataset.c.o
# [ 34%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/vlad.c.o
# [ 34%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/mathop_avx.c.o
# [ 34%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/imopv_sse2.c.o
# [ 34%] Building C object lib/VLFeat/CMakeFiles/vlfeat.dir/mathop_sse2.c.o
# [ 36%] Linking C static library libvlfeat.a
# [ 36%] Built target vlfeat
# [ 36%] Building NVCC (Device) object src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_patch_match_cuda.cu.o
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu: In member function ‘void colmap::mvs::PatchMatchCuda::InitRefImage()’:
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1437:85: warning: ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’ is deprecated [-Wdeprecated-declarations]
#    CUDA_SAFE_CALL(
#                                                                                      ^
# /usr/local/cuda/include/cuda_runtime.h:1537:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTextureToArray(
#                                                      ^~~~~~~~~~~~~~~~~~~~~~
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu: In member function ‘void colmap::mvs::PatchMatchCuda::InitSourceImages()’:
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1484:87: warning: ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = unsigned char; int dim = 242; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’ is deprecated [-Wdeprecated-declarations]
#      CUDA_SAFE_CALL(cudaBindTextureToArray(src_images_texture,
#                                                                                        ^
# /usr/local/cuda/include/cuda_runtime.h:1537:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTextureToArray(
#                                                      ^~~~~~~~~~~~~~~~~~~~~~
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1518:95: warning: ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = float; int dim = 242; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’ is deprecated [-Wdeprecated-declarations]
#      CUDA_SAFE_CALL(cudaBindTextureToArray(src_depth_maps_texture,
#                                                                                                ^
# /usr/local/cuda/include/cuda_runtime.h:1537:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTextureToArray(
#                                                      ^~~~~~~~~~~~~~~~~~~~~~
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu: In member function ‘void colmap::mvs::PatchMatchCuda::InitTransforms()’:
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1629:82: warning: ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = float; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’ is deprecated [-Wdeprecated-declarations]
#    CUDA_SAFE_CALL(
#                                                                                   ^
# /usr/local/cuda/include/cuda_runtime.h:1537:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTextureToArray(
#                                                      ^~~~~~~~~~~~~~~~~~~~~~
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu: In member function ‘void colmap::mvs::PatchMatchCuda::Rotate()’:
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1735:49: warning: ‘cudaError_t cudaUnbindTexture(const texture<T, dim, readMode>&) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError]’ is deprecated [-Wdeprecated-declarations]
#    CUDA_SAFE_CALL(cudaUnbindTexture(ref_image_texture));
#                                                  ^
# /usr/local/cuda/include/cuda_runtime.h:1661:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaUnbindTexture(
#                                                      ^~~~~~~~~~~~~~~~~
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1736:85: warning: ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’ is deprecated [-Wdeprecated-declarations]
#    CUDA_SAFE_CALL(
#                                                                                      ^
# /usr/local/cuda/include/cuda_runtime.h:1537:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTextureToArray(
#                                                      ^~~~~~~~~~~~~~~~~~~~~~
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1755:45: warning: ‘cudaError_t cudaUnbindTexture(const texture<T, dim, readMode>&) [with T = float; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError]’ is deprecated [-Wdeprecated-declarations]
#    CUDA_SAFE_CALL(cudaUnbindTexture(poses_texture));
#                                              ^
# /usr/local/cuda/include/cuda_runtime.h:1661:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaUnbindTexture(
#                                                      ^~~~~~~~~~~~~~~~~
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1756:101: warning: ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = float; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’ is deprecated [-Wdeprecated-declarations]
#    CUDA_SAFE_CALL(cudaBindTextureToArray(
#                                                                                                      ^
# /usr/local/cuda/include/cuda_runtime.h:1537:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTextureToArray(
#                                                      ^~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h: In instantiation of ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’:
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1437:85:   required from here
# /usr/local/cuda/include/cuda_runtime.h:1545:55: warning: ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t, const cudaChannelFormatDesc&) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’ is deprecated [-Wdeprecated-declarations]
#    return err == cudaSuccess ? cudaBindTextureToArray(tex, array, desc) : err;
#                                  ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h:1498:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTextureToArray(
#                                                      ^~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h: In instantiation of ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = unsigned char; int dim = 242; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’:
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1484:87:   required from here
# /usr/local/cuda/include/cuda_runtime.h:1545:55: warning: ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t, const cudaChannelFormatDesc&) [with T = unsigned char; int dim = 242; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’ is deprecated [-Wdeprecated-declarations]
#    return err == cudaSuccess ? cudaBindTextureToArray(tex, array, desc) : err;
#                                  ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h:1498:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTextureToArray(
#                                                      ^~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h: In instantiation of ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = float; int dim = 242; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’:
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1518:95:   required from here
# /usr/local/cuda/include/cuda_runtime.h:1545:55: warning: ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t, const cudaChannelFormatDesc&) [with T = float; int dim = 242; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’ is deprecated [-Wdeprecated-declarations]
#    return err == cudaSuccess ? cudaBindTextureToArray(tex, array, desc) : err;
#                                  ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h:1498:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTextureToArray(
#                                                      ^~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h: In instantiation of ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = float; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’:
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1629:82:   required from here
# /usr/local/cuda/include/cuda_runtime.h:1545:55: warning: ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t, const cudaChannelFormatDesc&) [with T = float; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’ is deprecated [-Wdeprecated-declarations]
#    return err == cudaSuccess ? cudaBindTextureToArray(tex, array, desc) : err;
#                                  ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h:1498:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTextureToArray(
#                                                      ^~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h: In instantiation of ‘cudaError_t cudaUnbindTexture(const texture<T, dim, readMode>&) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError]’:
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1735:49:   required from here
# /usr/local/cuda/include/cuda_runtime.h:1665:27: warning: ‘cudaError_t cudaUnbindTexture(const textureReference*)’ is deprecated [-Wdeprecated-declarations]
#    return ::cudaUnbindTexture(&tex);
#         ~~~~~~~~~~~~~~~~~~~^~~~~~
# /usr/local/cuda/include/cuda_runtime_api.h:8060:46: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaUnbindTexture(const struct textureReference *texref);
#                                               ^~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h: In instantiation of ‘cudaError_t cudaUnbindTexture(const texture<T, dim, readMode>&) [with T = float; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError]’:
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1755:45:   required from here
# /usr/local/cuda/include/cuda_runtime.h:1665:27: warning: ‘cudaError_t cudaUnbindTexture(const textureReference*)’ is deprecated [-Wdeprecated-declarations]
#    return ::cudaUnbindTexture(&tex);
#         ~~~~~~~~~~~~~~~~~~~^~~~~~
# /usr/local/cuda/include/cuda_runtime_api.h:8060:46: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaUnbindTexture(const struct textureReference *texref);
#                                               ^~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h: In instantiation of ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t, const cudaChannelFormatDesc&) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’:
# /usr/local/cuda/include/cuda_runtime.h:1545:55:   required from ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1437:85:   required from here
# /usr/local/cuda/include/cuda_runtime.h:1504:32: warning: ‘cudaError_t cudaBindTextureToArray(const textureReference*, cudaArray_const_t, const cudaChannelFormatDesc*)’ is deprecated [-Wdeprecated-declarations]
#    return ::cudaBindTextureToArray(&tex, array, &desc);
#         ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime_api.h:7994:46: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaBindTextureToArray(const struct textureReference *texref, cudaArray_const_t array, const struct cudaChannelFormatDesc *desc);
#                                               ^~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h: In instantiation of ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t, const cudaChannelFormatDesc&) [with T = unsigned char; int dim = 242; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’:
# /usr/local/cuda/include/cuda_runtime.h:1545:55:   required from ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = unsigned char; int dim = 242; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1484:87:   required from here
# /usr/local/cuda/include/cuda_runtime.h:1504:32: warning: ‘cudaError_t cudaBindTextureToArray(const textureReference*, cudaArray_const_t, const cudaChannelFormatDesc*)’ is deprecated [-Wdeprecated-declarations]
#    return ::cudaBindTextureToArray(&tex, array, &desc);
#         ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime_api.h:7994:46: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaBindTextureToArray(const struct textureReference *texref, cudaArray_const_t array, const struct cudaChannelFormatDesc *desc);
#                                               ^~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h: In instantiation of ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t, const cudaChannelFormatDesc&) [with T = float; int dim = 242; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’:
# /usr/local/cuda/include/cuda_runtime.h:1545:55:   required from ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = float; int dim = 242; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1518:95:   required from here
# /usr/local/cuda/include/cuda_runtime.h:1504:32: warning: ‘cudaError_t cudaBindTextureToArray(const textureReference*, cudaArray_const_t, const cudaChannelFormatDesc*)’ is deprecated [-Wdeprecated-declarations]
#    return ::cudaBindTextureToArray(&tex, array, &desc);
#         ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime_api.h:7994:46: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaBindTextureToArray(const struct textureReference *texref, cudaArray_const_t array, const struct cudaChannelFormatDesc *desc);
#                                               ^~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h: In instantiation of ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t, const cudaChannelFormatDesc&) [with T = float; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’:
# /usr/local/cuda/include/cuda_runtime.h:1545:55:   required from ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = float; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/patch_match_cuda.cu:1629:82:   required from here
# /usr/local/cuda/include/cuda_runtime.h:1504:32: warning: ‘cudaError_t cudaBindTextureToArray(const textureReference*, cudaArray_const_t, const cudaChannelFormatDesc*)’ is deprecated [-Wdeprecated-declarations]
#    return ::cudaBindTextureToArray(&tex, array, &desc);
#         ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime_api.h:7994:46: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaBindTextureToArray(const struct textureReference *texref, cudaArray_const_t array, const struct cudaChannelFormatDesc *desc);
#                                               ^~~~~~~~~~~~~~~~~~~~~~
# [ 38%] Building NVCC (Device) object src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_gpu_mat_prng.cu.o
# [ 38%] Building NVCC (Device) object src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_gpu_mat_ref_image.cu.o
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/gpu_mat_ref_image.cu: In member function ‘void colmap::mvs::GpuMatRefImage::Filter(const uint8_t*, size_t, size_t, float, float)’:
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/gpu_mat_ref_image.cu:110:72: warning: ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’ is deprecated [-Wdeprecated-declarations]
#    CUDA_SAFE_CALL(cudaBindTextureToArray(image_texture, image_array.GetPtr()));
#                                                                         ^
# /usr/local/cuda/include/cuda_runtime.h:1537:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTextureToArray(
#                                                      ^~~~~~~~~~~~~~~~~~~~~~
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/gpu_mat_ref_image.cu:115:45: warning: ‘cudaError_t cudaUnbindTexture(const texture<T, dim, readMode>&) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError]’ is deprecated [-Wdeprecated-declarations]
#    CUDA_SAFE_CALL(cudaUnbindTexture(image_texture));
#                                              ^
# /usr/local/cuda/include/cuda_runtime.h:1661:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaUnbindTexture(
#                                                      ^~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h: In instantiation of ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’:
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/gpu_mat_ref_image.cu:110:72:   required from here
# /usr/local/cuda/include/cuda_runtime.h:1545:55: warning: ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t, const cudaChannelFormatDesc&) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’ is deprecated [-Wdeprecated-declarations]
#    return err == cudaSuccess ? cudaBindTextureToArray(tex, array, desc) : err;
#                                  ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h:1498:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTextureToArray(
#                                                      ^~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h: In instantiation of ‘cudaError_t cudaUnbindTexture(const texture<T, dim, readMode>&) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError]’:
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/gpu_mat_ref_image.cu:115:45:   required from here
# /usr/local/cuda/include/cuda_runtime.h:1665:27: warning: ‘cudaError_t cudaUnbindTexture(const textureReference*)’ is deprecated [-Wdeprecated-declarations]
#    return ::cudaUnbindTexture(&tex);
#         ~~~~~~~~~~~~~~~~~~~^~~~~~
# /usr/local/cuda/include/cuda_runtime_api.h:8060:46: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaUnbindTexture(const struct textureReference *texref);
#                                               ^~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h: In instantiation of ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t, const cudaChannelFormatDesc&) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’:
# /usr/local/cuda/include/cuda_runtime.h:1545:55:   required from ‘cudaError_t cudaBindTextureToArray(const texture<T, dim, readMode>&, cudaArray_const_t) [with T = unsigned char; int dim = 2; cudaTextureReadMode readMode = (cudaTextureReadMode)1; cudaError_t = cudaError; cudaArray_const_t = const cudaArray*]’
# /content/ceres-solver/build/colmap/build/colmap/src/mvs/gpu_mat_ref_image.cu:110:72:   required from here
# /usr/local/cuda/include/cuda_runtime.h:1504:32: warning: ‘cudaError_t cudaBindTextureToArray(const textureReference*, cudaArray_const_t, const cudaChannelFormatDesc*)’ is deprecated [-Wdeprecated-declarations]
#    return ::cudaBindTextureToArray(&tex, array, &desc);
#         ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime_api.h:7994:46: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaBindTextureToArray(const struct textureReference *texref, cudaArray_const_t array, const struct cudaChannelFormatDesc *desc);
#                                               ^~~~~~~~~~~~~~~~~~~~~~
# [ 38%] Building CXX object src/CMakeFiles/colmap_cuda.dir/mvs/patch_match.cc.o
# [ 38%] Building CXX object src/CMakeFiles/colmap_cuda.dir/util/cuda.cc.o
# [ 40%] Building CXX object src/CMakeFiles/colmap_cuda.dir/util/cudacc.cc.o
# [ 40%] Linking CXX static library libcolmap_cuda.a
# [ 40%] Built target colmap_cuda
# [ 40%] Automatic RCC for ui/resources.qrc
# [ 40%] Building CXX object src/CMakeFiles/colmap.dir/base/camera.cc.o
# In file included from /usr/local/include/ceres/ceres.h:67:0,
#                  from /content/ceres-solver/build/colmap/build/colmap/src/base/camera_models.h:42,
#                  from /content/ceres-solver/build/colmap/build/colmap/src/base/camera.cc:36:
# /usr/local/include/ceres/product_manifold.h: In static member function ‘static std::array<T, N> ceres::ProductManifold<Manifold0, Manifold1, ManifoldN>::ExclusiveScan(const std::array<T, N>&)’:
# /usr/local/include/ceres/product_manifold.h:260:10: error: ‘exclusive_scan’ is not a member of ‘std’
#      std::exclusive_scan(values.begin(), values.end(), result.begin(), 0);
#           ^~~~~~~~~~~~~~
# src/CMakeFiles/colmap.dir/build.make:121: recipe for target 'src/CMakeFiles/colmap.dir/base/camera.cc.o' failed
# make[2]: *** [src/CMakeFiles/colmap.dir/base/camera.cc.o] Error 1
# CMakeFiles/Makefile2:691: recipe for target 'src/CMakeFiles/colmap.dir/all' failed
# make[1]: *** [src/CMakeFiles/colmap.dir/all] Error 2
# Makefile:135: recipe for target 'all' failed
# make: *** [all] Error 2
# -- Found AMD headers in: /usr/include/suitesparse
# -- Found AMD library: /usr/lib/x86_64-linux-gnu/libamd.so
# -- Found CAMD headers in: /usr/include/suitesparse
# -- Found CAMD library: /usr/lib/x86_64-linux-gnu/libcamd.so
# -- Found CCOLAMD headers in: /usr/include/suitesparse
# -- Found CCOLAMD library: /usr/lib/x86_64-linux-gnu/libccolamd.so
# -- Found CHOLMOD headers in: /usr/include/suitesparse
# -- Found CHOLMOD library: /usr/lib/x86_64-linux-gnu/libcholmod.so
# -- Found COLAMD headers in: /usr/include/suitesparse
# -- Found COLAMD library: /usr/lib/x86_64-linux-gnu/libcolamd.so
# -- Found SPQR headers in: /usr/include/suitesparse
# -- Found SPQR library: /usr/lib/x86_64-linux-gnu/libspqr.so
# -- Found Config headers in: /usr/include/suitesparse
# -- Found Config library: /usr/lib/x86_64-linux-gnu/libsuitesparseconfig.so
# -- Did not find Intel TBB library, assuming SuiteSparseQR was not compiled with TBB.
# -- Adding librt to SuiteSparse_config libraries (required on Linux & Unix [not OSX] if SuiteSparse is compiled with timing).
# -- Found required Ceres dependency: Eigen version 3.3.4 in /usr/lib/cmake/eigen3
# -- Found required Ceres dependency: glog
# -- Found required Ceres dependency: gflags
# -- Found Ceres version: 2.2.0 installed in: /usr/local with components: [EigenSparse, SparseLinearAlgebraLibrary, LAPACK, SuiteSparse, SchurSpecializations, Multithreading]
# -- Found Eigen
# --   Includes : /usr/include/eigen3
# -- Found FreeImage
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libfreeimage.so
# -- Found Metis
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libmetis.so
# -- Found Glog
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libglog.so
# -- Found Glew
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libGLEW.so
# -- Found Qt
# --   Module : /usr/lib/x86_64-linux-gnu/cmake/Qt5Core
# --   Module : /usr/lib/x86_64-linux-gnu/cmake/Qt5OpenGL
# --   Module : /usr/lib/x86_64-linux-gnu/cmake/Qt5Widgets
# -- Found CGAL
# --   Includes : /usr//include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libCGAL.so.13.0.1
# -- Build type not specified, using Release
# -- Enabling SIMD support
# -- Enabling OpenMP support
# -- Disabling interprocedural optimization
# -- Automatic GPU detection failed. Building for common architectures.
# -- Autodetected CUDA architecture(s): 3.5;5.0;5.2;6.0;6.1;7.0;7.5;8.0;8.6;8.6+PTX
# -- Enabling CUDA support (version: 11.1, archs: sm_35 sm_50 sm_52 sm_60 sm_61 sm_70 sm_75 sm_80 sm_86 compute_86)
# -- Enabling GUI support
# -- Enabling OpenGL support
# -- Disabling ccache support
# -- Disabling profiling support
# -- Enabling CGAL support
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /content/ceres-solver/build/colmap/build/colmap/build
# Consolidate compiler generated dependencies of target flann
# [  2%] Built target flann
# Consolidate compiler generated dependencies of target lsd
# [  2%] Built target lsd
# [  2%] Building NVCC (Device) object lib/PBA/CMakeFiles/pba.dir/pba_generated_ProgramCU.cu.o
# Consolidate compiler generated dependencies of target pba
# [  2%] Linking CXX static library libpba.a
# [  6%] Built target pba
# Consolidate compiler generated dependencies of target poisson_recon
# [  9%] Built target poisson_recon
# [ 11%] Building NVCC (Device) object lib/SiftGPU/CMakeFiles/sift_gpu.dir/sift_gpu_generated_ProgramCU.cu.o
# Consolidate compiler generated dependencies of target sift_gpu
# [ 11%] Linking CXX static library libsift_gpu.a
# [ 15%] Built target sift_gpu
# Consolidate compiler generated dependencies of target sqlite3
# [ 18%] Built target sqlite3
# Consolidate compiler generated dependencies of target vlfeat
# [ 36%] Built target vlfeat
# [ 36%] Building NVCC (Device) object src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_patch_match_cuda.cu.o

# %% [markdown]
# Next, we need to prepare the images to run colmap.
# First, create a folder in your google drive and a subfolder named `images`, and put your images inside.

# %% [markdown]
# ## Mount your drive (to access data)

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Clone LLFF util

# %%
# %cd /content
# !git clone https://github.com/Fyusion/LLFF
# Out:
# /content
# Cloning into 'LLFF'...
# remote: Enumerating objects: 774, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 774 (delta 7), reused 20 (delta 5), pack-reused 748
# Receiving objects: 100% (774/774), 31.94 MiB | 26.17 MiB/s, done.
# Resolving deltas: 100% (409/409), done.

# %% [markdown]
# # Run COLMAP! (depending on number of images, this takes 10~20 minutes)

# %%
dataset='brighton' #@param ['brighton','louvre']
# %cd /content/LLFF
# # change the path below to your data folder (the folder containing the `images` folder)
# !python imgs2poses.py "/content/drive/My Drive/COMP0132/{dataset}/"

# The project folder must contain a folder "images" with all the images.

# !DATASET_PATH=/content/drive/MyDrive/COMP0132/{dataset}

# !colmap feature_extractor \
 --database_path $DATASET_PATH/database.db \
  --image_path $DATASET_PATH/images

# !colmap exhaustive_matcher \
  --database_path $DATASET_PATH/database.db

# !mkdir $DATASET_PATH/sparse

# !colmap mapper \
   --database_path $DATASET_PATH/database.db \
   --image_path $DATASET_PATH/images \
   --output_path $DATASET_PATH/sparse

# !mkdir $DATASET_PATH/dense

# !colmap image_undistorter \
   --image_path $DATASET_PATH/images \
   --input_path $DATASET_PATH/sparse/0 \
   --output_path $DATASET_PATH/dense \
   --output_type COLMAP \
   --max_image_size 2000

# !colmap patch_match_stereo \
   --workspace_path $DATASET_PATH/dense \
   --workspace_format COLMAP \
   --PatchMatchStereo.geom_consistency true

# !colmap stereo_fusion \
   --workspace_path $DATASET_PATH/dense \
   --workspace_format COLMAP \
   --input_type geometric \
   --output_path $DATASET_PATH/dense/fused.ply

# !colmap poisson_mesher \
   --input_path $DATASET_PATH/dense/fused.ply \
   --output_path $DATASET_PATH/dense/meshed-poisson.ply

# !colmap delaunay_mesher \
   --input_path $DATASET_PATH/dense \
   --output_path $DATASET_PATH/dense/meshed-delaunay.ply
# Out:
# /bin/bash: colmap: command not found
# /bin/bash: colmap: command not found
# mkdir: cannot create directory ‘/sparse’: File exists
# /bin/bash: colmap: command not found
# mkdir: cannot create directory ‘/dense’: File exists
# /bin/bash: colmap: command not found
# /bin/bash: colmap: command not found
# /bin/bash: colmap: command not found
# /bin/bash: colmap: command not found
# /bin/bash: colmap: command not found

# %% [markdown]
# After running colmap, you will get a `poses_bounds.npy` file under your data folder, once you got that, you're ready to train!

# %%
# Display mesh .ply 
! pip install open3d-python
import numpy as np
from open3d import *
cloud_poisson = read_point_cloud("meshed-poisson.ply") # Read the point cloud
cloud_delaunay = read_point_cloud("meshed-delaunay.ply") # Read the point cloud
cloud_fused = read_point_cloud("fused.ply")

draw_geometries([cloud_poisson]) # Visualize the poisson point cloud
